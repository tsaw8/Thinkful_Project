# %% [markdown]
# ### Context
# #### In this assignment, we will:
# 1. Determine the five most common journals and the total articles for each
# 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal
# 3. BONUS: Identify the open access prices paid by subject area

# %%
# Libraries

import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from matplotlib import pyplot
import re
import seaborn as sns
# %matplotlib inline

# %%
# Import data by iso-8859-1 encoding

data = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='iso-8859-1')
data.columns = ['PMID/PMCID', 'Publisher', 'Journal title', 'Article title','Cost']
data_clean = data
data_clean.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title      Cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
data_clean.dtypes
# Out:
# PMID/PMCID       object
# Publisher        object
# Journal title    object
# Article title    object
# Cost             object
# dtype: object

# %% [markdown]
# First, we will clean the journal titles by casting them in the title case, stripping additional white spaces, and convert to lower case. We will also replace spaces with underscores. Then, we will see how many times each title occurs. To see if we have made progress with cleaning the Journal title column, we will view number of titles that only occur once as errors.

# %%
# Clean journal title column with using title case and strip whitespcae

data_clean['Journal title'] = data['Journal title'].apply(lambda x: str(x).title())
data_clean['Journal title'] = data['Journal title'].apply(lambda x: str(x).strip())
data_clean['Journal title'] = data['Journal title'].apply(lambda x: str(x).lower())
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace(' ','_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('__','_'))

# %%
# Count occurance of titles

data_clean['count'] = data_clean.groupby('Journal title')['Journal title'].transform('count')
data_clean['count'] = data_clean['count'].sort_values()
len(data_clean[data_clean['count']==1])
# Out:
# 566

# %% [markdown]
# Our previous method has not been very effective since there are 566 titles that occur only once. Next, we will attempt to establish title consistency by replacing abbreviations with the full form of the word and removing forms of journal form the title.

# %%
# Clean inconsistent journal names by spelling out abbreviations

data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('j_',''))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('journal_of_',''))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('jnl_',''))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('the_',''))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('int_','international_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('med_','medicinal_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('sci.','science'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('chem_','chemistry_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('org_','organic_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('mol_','molecular_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('biol','biological'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('chem.','chemistry_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('pharm_','pharmaceutics_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('acs','american_chemical_society'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('americal_','american_'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('blood_journal_2012','blood'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('aids','acquired_immune_deficiency_syndromes'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('bmc','biomed_central'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('sex','sexually'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('transm','transmitted'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('behavior','behaviour'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('pnas','proceedings_of_the_national_academy_of_sciences'))
data_clean['Journal title'] = data_clean['Journal title'].apply(lambda x: str(x).replace('proceddings','proceedings_'))

# %%
data_clean['count'] = data_clean.groupby('Journal title')['Journal title'].transform('count')
data_clean['count'] = data_clean['count'].sort_values()
len(data_clean[data_clean['count']==1])
# Out:
# 526

# %% [markdown]
# Now that the journal title column is a bit more clean, we will start modifying the price column. The data in the price column is formatted as a string. We will need to convert the data to numeric values and removed the currency symbol into another column.

# %%
# Create and clean the price column using a regular expression to assign numeric format

data_clean['Price'] = data_clean['Cost'].str.findall(r'\d+[.]\d+')
data_clean['Price'] = data_clean['Price'].apply(lambda x: x[0] if x else 0)
data_clean['Price'] = data_clean['Price'].apply(lambda x: pd.to_numeric(x))
data_clean['Price'].head()
# Out:
# 0       0.00
# 1    2381.04
# 2     642.56
# 3     669.64
# 4     685.88
# Name: Price, dtype: float64

# %%
# Assign currency to their own column using regex 

data_clean['Currency'] = data_clean['Cost'].str.findall(r'£')
data_clean['Currency'] = data_clean['Cost'].str.findall(r'$')
# NOTE: currency sign did not carry over

# %%
# Columns with null values

data_clean.isnull().sum()
# Out:
# PMID/PMCID       199
# Publisher          0
# Journal title      0
# Article title      0
# Cost               0
# count              0
# Price              0
# Currency           0
# dtype: int64

# %% [markdown]
# Since there are not any missing values in the journal title or price column, we will check if there are potentially any incorrect values in the price column with a boxplot.

# %%
ax = sns.boxplot(x=data_clean['Price'])

# %% [markdown]
# There are mulitple high price points beyond the upper tail of the boxplot. Let's take a closer look at these outliers in the top 3%.

# %%
# Check for outliers

price_outliers = data_clean[data_clean['Price'] > data_clean['Price'].quantile(.97)]
print(price_outliers)
# Out:
#                                             PMID/PMCID  \
# 149                                         PMC3234811
# 227                                            3708772
# 277                                        PMC3668259
# 358                                         PMC3219211
# 404                                         PMC3533396
# 410                                                NaN
# 490                                         PMC3650559
# 491                                  PMCID: PMC3464430
# 526                                                NaN
# 552                                23541370 PMC3744751
# 560                                         PMC3632754
# 630    Epub ahead of print April 2013 - print in press
# 648                                                NaN
# 660                           PMID:23291342 PMC3581773
# 668                                  PMCID: PMC3594747
# 669                                         PMC3594749
# 670                                  PMCID: PMC3679449
# 729                                            2875410
# 796                                         PMC3525981
# 797                                                NaN
# 798                           PMCID:\n    PMC3627205\n
# 799                                                NaN
# 800                  PMID: 23041239 /PMCID: PMC3490334
# 811                                                NaN
# 815                                                NaN
# 825                                                NaN
# 829                              23200744  PMC3552157
# 841                                23394834 PMC3629559
# 844                               23498957 PMC3601332
# 873                                     PMC3644713\n\n
# ...                                                ...
# 1046                                        PMC3709478
# 1065                                 PMCID: PMC3615658
# 1138                                        PMC3510758
# 1208  Epub ahead of print pub Jan 2013, print in press
# 1256                               23981980 PMC3809720
# 1309                                           2294692
# 1367                            PMCID:    PMC3531293\n
# 1386                                        PMC3527207
# 1387                                               NaN
# 1470                                           3547931
# 1560                                           3726600
# 1561                                          23285297
# 1562                                       PMC3720940
# 1563                                 PMCID: PMC3748079
# 1564                            PMCID:\n    PMC3579793
# 1565                            PMCID:\n    PMC3732248
# 1566                          PMCID:\n    PMC3767740\n
# 1597                                 PMCID: PMC3749955
# 1598                          PMCID:\n    PMC3764210\n
# 1612                                      PMC3777952\n
# 1614                                       PMC 3712914
# 1616                                       PMC 3460945
# 1619                                            543219
# 1664                                (PMCID:PMC3757918)
# 1675                                 Not yet available
# 1835                                  PMCID:PMC3268392
# 1939                                               NaN
# 1947                                               NaN
# 1961                                        PMC3557719
# 1987                                    PMC3664409\n\n
#
#                                               Publisher  \
# 149                                               ASBMB
# 227                                     BioMed Central
# 277                                                 BMC
# 358                          Cambridge University Press
# 404                               Company of Biologists
# 410                                                 CUP
# 490                                            Elsevier
# 491                                            Elsevier
# 526                                            Elsevier
# 552                                            Elsevier
# 560                                            Elsevier
# 630                                            Elsevier
# 648                                            Elsevier
# 660                                            Elsevier
# 668                                            Elsevier
# 669                                            Elsevier
# 670                                            Elsevier
# 729                                            Elsevier
# 796                                            Elsevier
# 797                                            Elsevier
# 798                                            Elsevier
# 799                                            Elsevier
# 800                                            Elsevier
# 811                                            Elsevier
# 815                                            Elsevier
# 825                                            Elsevier
# 829                                            Elsevier
# 841                                       Elsevier B.V.
# 844                                 Elsevier/Cell Press
# 873                                           Frontiers
# ...                                                 ...
# 1046                                             Nature
# 1065                            Nature Publishing Group
# 1138                                                OUP
# 1208                            Oxford University Press
# 1256                            Oxford University Press
# 1309                                               PNAS
# 1367                          Public Library of Science
# 1386                          Public Library of Science
# 1387                          Public Library of Science
# 1470                          Public Library of Science
# 1560                          Public Library of Science
# 1561                          Public Library of Science
# 1562                          Public Library of Science
# 1563                          Public Library of Science
# 1564                          Public Library of Science
# 1565                          Public Library of Science
# 1566                          Public Library of Science
# 1597                          Public Library of Science
# 1598                          Public Library of Science
# 1612                          Public Library of Science
# 1614                          Public Library of Science
# 1616                          Public Library of Science
# 1619                               public.service.co.uk
# 1664                                               Sage
# 1675                                    Sage Publishing
# 1835  The American Society for Biochemistry and Mole...
# 1939                                              Wiley
# 1947                                              Wiley
# 1961                                              Wiley
# 1987                                              Wiley
#
#                                         Journal title  \
# 149                        biologicalogical_chemistry
# 227                          biomed_central_genomics.
# 277                                            trials
# 358              expert_reviews_in_molecular_medicine
# 404                                      cell_science
# 410                   international_african_institute
# 490                                              cell
# 491                                              cell
# 526                             current_biologicalogy
# 552                                          elsevier
# 560                        experimental_cell_research
# 630                                paediatric_urology
# 648                                            lancet
# 660                molecluar_&_cellular_endocrinology
# 668                                    molecular_cell
# 669                                    molecular_cell
# 670                                    molecular_cell
# 729                                            neuron
# 796                                            lancet
# 797                                            lancet
# 798                                            lancet
# 799                                  lancet_neurology
# 800                                  lancet_neurology
# 811                           trends_in_neurosciences
# 815                            trends_in_parasitology
# 825                           veterinary_parasitology
# 829                                   vision_research
# 841                                  curr_biological.
# 844                               cell_host_&_microbe
# 873                            frontiers_in_cognition
# ...                                               ...
# 1046                            nature_communications
# 1065                                     embo_reports
# 1138                         human_molecular_genetics
# 1208                                  cerebral_cortex
# 1256                          oxford_university_press
# 1309  proceedings_of_the_national_academy_of_sciences
# 1367                 plos_computational_biologicalogy
# 1386                                    plos_genetics
# 1387                                    plos_genetics
# 1470                                         plos_one
# 1560                                         plos_one
# 1561                                         plos_one
# 1562                                         plos_one
# 1563                                         plos_one
# 1564                                         plos_one
# 1565                                         plos_one
# 1566                                         plos_one
# 1597                                   plos_pathogens
# 1598                                   plos_pathogens
# 1612                                          plosone
# 1614                             pmedicine-d-12-03130
# 1616                                   pone-d12-17947
# 1619                            public_service_review
# 1664                        history_of_human_sciences
# 1675                             qualitative_research
# 1835                       biologicalogical_chemistry
# 1939                          hbm_human_brain_mapping
# 1947                                      hippocampus
# 1961                                   neurochemistry
# 1987                               movement_disorders
#
#                                           Article title        Cost  count  \
# 149   Picomolar nitric oxide signals from central ne...  £999999.00     64
# 227   Phenotypic, genomic, and transcriptional chara...  £999999.00      1
# 277   Community resource centres to improve the heal...  £999999.00      5
# 358   Pharmacological targets in the ubiquitin syste...  £999999.00      1
# 404   PKA isoforms coordinate mRNA fate during nutri...  £999999.00      9
# 410         Pharmacy, money and public health in Dakar.  £999999.00      3
# 490   Mapping the human miRNA interactome by CLASH r...    £4163.88      5
# 491   piRNAs can trigger a multigenerational epigene...  £999999.00      5
# 526                  A fovea for pain at the fingertips    £4112.54     11
# 552   Effects of relative weight gain and linear gro...    £4800.00      7
# 560   Perturbation of invadolysin disrupts cell migr...  £999999.00      1
# 630   Persistent unexplained congenital clitoromegal...  £999999.00      1
# 648   Global trends in antiretroviral resistance in ...    £4800.00      5
# 660   Periconceptional changes in maternal exposure ...  £999999.00      1
# 668   Identification and Functional Characterization...    £4148.39      5
# 669   Bax Exists in a Dynamic Equilibrium between th...  £999999.00      5
# 670   Kinetochores coordinate pericentromeric cohesi...  £999999.00      5
# 729   Distinct contributions of rod, cone, and melan...    £4170.35      9
# 796   Dementia incidence and mortality in middle inc...    £4320.00      5
# 797   The impact on a serogroup a meningococcal conj...    £4554.01      5
# 798   Effects of unconditional and conditional cash ...    £4800.00      5
# 799   MRI investigation of the sensorimotor cortex a...    £4320.00      2
# 800   Genetic risk factors for ischaemic stroke and ...    £5760.00      2
# 811   Cytoplasmic dynein heavy chain: the servant of...  £999999.00      2
# 815   Infection and treatment immunizations for succ...  £999999.00      4
# 825   Persistence of the efficacy of copper oxide wi...  £999999.00      2
# 829   Perceptual learning of second order cues for l...  £999999.00      2
# 841   Calcium flashes orchestrate the wound inflamma...    £4151.77      1
# 844   Human cytomegalovirus UL141 targets the TRAIL ...    £4226.04      1
# 873   Persistence of internal representations of alt...  £999999.00      1
# ...                                                 ...         ...    ...
# 1046  Picornavirus uncoating intermediate captured i...  £999999.00     19
# 1065  Physiological release of endogenous tau is sti...  £999999.00      3
# 1138  Genome Wide Meta-analysis points to CTC1 and Z...  £999999.00     19
# 1208  Pharmacological dissociation of novelty respon...  £999999.00      7
# 1256  Physical activity levels across adult life and...  £999999.00      1
# 1309  Shaping accoustic fields as a toolset for micr...  £999999.00      6
# 1367  Phylodynamic inference and model assessment wi...  £999999.00     10
# 1386  Population genomics of the Wolbachia endosymbi...  £999999.00     24
# 1387  PNUTS/PP1 regulates RNAPII-mediated gene expre...  £999999.00     24
# 1470  Reducing stock-outs of life saving Malaria Com...  £192645.00    191
# 1560  Plasmodium falciparum vary Gene Expression Hom...  £999999.00    191
# 1561  Pharmacological inhibition of caspase-2 protec...  £999999.00    191
# 1562  Population-based CD4 counts in a rural area in...  £999999.00    191
# 1563  Plant SILAC: stable-isotope labelling with ami...  £999999.00    191
# 1564  Phagocytosis Is the Main CR3-Mediated Function...  £999999.00    191
# 1565  Pneumocystis jirovecii pneumonia in tropical a...  £999999.00    191
# 1566  Phenotypic alteration of neutrophils in the bl...  £999999.00    191
# 1597  Determinants of GPI-PLC localisation to the fl...  £999999.00     24
# 1598  The CLIP-domain serine protease homolog SPCLIP...  £999999.00     24
# 1612  Retinal Nerve Fibre Layer Thickness and Contra...  £999999.00      9
# 1614  Global Burden of Sickle cell Anaemia in childr...  £999999.00      1
# 1616  Persistence of Hyperinvasive Meningococcal Str...  £999999.00      1
# 1619            Laboratory Science in Tropical Medicine    £6000.00      1
# 1664  How autism became autism: the radical transfor...  £999999.00      5
# 1675  Picturing commuting: photovoice and seeking we...  £999999.00      1
# 1835  Photoaffinity labelling of high affinity nicot...  £999999.00     64
# 1939  Phase informed model for motion and susceptibi...  £999999.00      1
# 1947  Pituitary adenylate cyclase-activating polypep...  £999999.00      5
# 1961  Pituitary adenylate cyclase-activating peptide...  £999999.00      5
# 1987  Limb amputations in fixed dystonia: a form of ...  £201024.00     15
#
#           Price Currency
# 149   999999.00       []
# 227   999999.00       []
# 277   999999.00       []
# 358   999999.00       []
# 404   999999.00       []
# 410   999999.00       []
# 490     4163.88       []
# 491   999999.00       []
# 526     4112.54       []
# 552     4800.00       []
# 560   999999.00       []
# 630   999999.00       []
# 648     4800.00       []
# 660   999999.00       []
# 668     4148.39       []
# 669   999999.00       []
# 670   999999.00       []
# 729     4170.35       []
# 796     4320.00       []
# 797     4554.01       []
# 798     4800.00       []
# 799     4320.00       []
# 800     5760.00       []
# 811   999999.00       []
# 815   999999.00       []
# 825   999999.00       []
# 829   999999.00       []
# 841     4151.77       []
# 844     4226.04       []
# 873   999999.00       []
# ...         ...      ...
# 1046  999999.00       []
# 1065  999999.00       []
# 1138  999999.00       []
# 1208  999999.00       []
# 1256  999999.00       []
# 1309  999999.00       []
# 1367  999999.00       []
# 1386  999999.00       []
# 1387  999999.00       []
# 1470  192645.00       []
# 1560  999999.00       []
# 1561  999999.00       []
# 1562  999999.00       []
# 1563  999999.00       []
# 1564  999999.00       []
# 1565  999999.00       []
# 1566  999999.00       []
# 1597  999999.00       []
# 1598  999999.00       []
# 1612  999999.00       []
# 1614  999999.00       []
# 1616  999999.00       []
# 1619    6000.00       []
# 1664  999999.00       []
# 1675  999999.00       []
# 1835  999999.00       []
# 1939  999999.00       []
# 1947  999999.00       []
# 1961  999999.00       []
# 1987  201024.00       []
#
# [64 rows x 8 columns]

# %% [markdown]
# There are several articles that are priced at £999999.00 which may have been an indicator of missing values. We will replace £999999.00 with NaN and then substitue it with the mean price for that journal.

# %%
# Compute the mean price of each article

data_clean[data_clean['Price'] == 999999.00] = None
mean = data_clean.groupby(['Journal title'])['Price'].mean()
data_clean['Price'] = data_clean['Price'].fillna(mean)

# %% [markdown]
# Now, let's check for outliers in the top 1% of the dataset.

# %%
# Check for outliers

price_outliers = data_clean[data_clean['Price'] > data_clean['Price'].quantile(.99)]
print(price_outliers)
# Out:
#                              PMID/PMCID                  Publisher  \
# 490                          PMC3650559                   Elsevier
# 526                                 NaN                   Elsevier
# 542                             3605578                   Elsevier
# 552                 23541370 PMC3744751                   Elsevier
# 648                                 NaN                   Elsevier
# 668                   PMCID: PMC3594747                   Elsevier
# 728                          PMC3748348                   Elsevier
# 729                             2875410                   Elsevier
# 786                   PMCID: PMC3694306                   Elsevier
# 796                          PMC3525981                   Elsevier
# 797                                 NaN                   Elsevier
# 798            PMCID:\n    PMC3627205\n                   Elsevier
# 799                                 NaN                   Elsevier
# 800   PMID: 23041239 /PMCID: PMC3490334                   Elsevier
# 831                          PMC3685808                  Elsevier
# 841                 23394834 PMC3629559              Elsevier B.V.
# 844                23498957 PMC3601332         Elsevier/Cell Press
# 986                                 NaN                  MacMillan
# 1470                            3547931  Public Library of Science
# 1619                             543219       public.service.co.uk
# 1987                     PMC3664409\n\n                      Wiley
#
#               Journal title  \
# 490                    cell
# 526   current_biologicalogy
# 542      developmental_cell
# 552                elsevier
# 648                  lancet
# 668          molecular_cell
# 728                  neuron
# 729                  neuron
# 786               structure
# 796                  lancet
# 797                  lancet
# 798                  lancet
# 799        lancet_neurology
# 800        lancet_neurology
# 831         cell_metabolism
# 841        curr_biological.
# 844     cell_host_&_microbe
# 986                     nan
# 1470               plos_one
# 1619  public_service_review
# 1987     movement_disorders
#
#                                           Article title        Cost  count  \
# 490   Mapping the human miRNA interactome by CLASH r...    £4163.88    5.0
# 526                  A fovea for pain at the fingertips    £4112.54   11.0
# 542   Syndecan-4 phosphorylation is a control point ...    £4099.71   12.0
# 552   Effects of relative weight gain and linear gro...    £4800.00    7.0
# 648   Global trends in antiretroviral resistance in ...    £4800.00    5.0
# 668   Identification and Functional Characterization...    £4148.39    5.0
# 728   Attention induced variance and noise correclat...    £4105.34    9.0
# 729   Distinct contributions of rod, cone, and melan...    £4170.35    9.0
# 786   The architecture of EssB, an integral membrane...    £4095.97    7.0
# 796   Dementia incidence and mortality in middle inc...    £4320.00    5.0
# 797   The impact on a serogroup a meningococcal conj...    £4554.01    5.0
# 798   Effects of unconditional and conditional cash ...    £4800.00    5.0
# 799   MRI investigation of the sensorimotor cortex a...    £4320.00    2.0
# 800   Genetic risk factors for ischaemic stroke and ...    £5760.00    2.0
# 831   Improved insulin sensitivity despite increased...    £4084.51    3.0
# 841   Calcium flashes orchestrate the wound inflamma...    £4151.77    1.0
# 844   Human cytomegalovirus UL141 targets the TRAIL ...    £4226.04    1.0
# 986   Fungal Disease in Britain and the United State...   £13200.00    1.0
# 1470  Reducing stock-outs of life saving Malaria Com...  £192645.00  191.0
# 1619            Laboratory Science in Tropical Medicine    £6000.00    1.0
# 1987  Limb amputations in fixed dystonia: a form of ...  £201024.00   15.0
#
#           Price Currency
# 490     4163.88       []
# 526     4112.54       []
# 542     4099.71       []
# 552     4800.00       []
# 648     4800.00       []
# 668     4148.39       []
# 728     4105.34       []
# 729     4170.35       []
# 786     4095.97       []
# 796     4320.00       []
# 797     4554.01       []
# 798     4800.00       []
# 799     4320.00       []
# 800     5760.00       []
# 831     4084.51       []
# 841     4151.77       []
# 844     4226.04       []
# 986    13200.00       []
# 1470  192645.00       []
# 1619    6000.00       []
# 1987  201024.00       []

# %% [markdown]
# If we look at the last four rows, the prices are super high compared to other prices. The maxium value is priced at £201024.00. This may have been a decimal placement error since most of the prices in the top 1% are around £4000.00. So we will move the decimal to the proper place to eliminate outliers.

# %%
# Moving decimal place of price outliers

data_clean['Price'].replace(201024.00, 2010.24, inplace=True)
data_clean['Price'].replace(192645.00, 1926.45, inplace=True)
data_clean['Price'].replace(13200.00, 1320.00, inplace=True)
data_clean['Price'].replace(6000.00, 600.00, inplace=True)

# %% [markdown]
# Now we are ready to answer the questions.
#
# #### 1. Determine the five most common journals and the total articles for each

# %%
data_clean['Journal title'].value_counts()[:5]
# Out:
# plos_one                      184
# biologicalogical_chemistry     62
# neuroimage                     29
# nucleic_acids_research         26
# plos_genetics                  22
# Name: Journal title, dtype: int64

# %% [markdown]
# #### 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal

# %%
data_clean['Price'].groupby(data_clean['Journal title']).describe()
# Out:
#                                                     count         mean  \
# Journal title
# abnormal_child_psychology_and_psychiatry              1.0  2247.340000
# abnormal_psychology                                   1.0  2534.530000
# academy_of_nutrition_and_dietetics                    1.0  2379.540000
# acquired_immune_deficiency_syndromes                  5.0  2044.464000
# acquired_immune_deficiency_syndromes_behav            1.0  1834.770000
# acquired_immune_deficiency_syndromes_care             4.0  2294.225000
# acquired_immune_deficiency_syndromes_journal          1.0  2015.720000
# acquired_immune_deficiency_syndromes_research_a...    1.0  1240.000000
# acquired_immune_deficiency_syndromes_uk               2.0  1836.920000
# acquired_immune_deficiency_syndroms_(jacquired_...    1.0  1836.920000
# acta_crystallographica,_section_d                     1.0   757.180000
# acta_crystallographica_section_d,_biologicalogi...    1.0   771.420000
# acta_crystallographica_section_d:_biologicalogi...    1.0   773.740000
# acta_crystallographica_section_f:_structural_bi...    2.0   796.635000
# acta_crystallography_d                                1.0   774.190000
# acta_d                                                1.0   750.160000
# acta_dermato_venereologica                            1.0   653.960000
# acta_diabetologica                                    1.0  2336.280000
# acta_f                                                1.0   754.900000
# acta_neuropathol                                      1.0  1901.040000
# acta_neuropathologica                                 3.0  2161.063333
# acta_opthalmologica                                   1.0  2270.160000
# acta_physiol                                          1.0  1991.500000
# addiction                                             2.0  2136.225000
# advances_in_experimental_medicine_and_biologica...    4.0  1928.457500
# affective_disorders                                   4.0  2123.720000
# age                                                   2.0  2170.140000
# age_and_ageing                                        1.0  2040.000000
# ageing_&_society                                      1.0  1695.000000
# aging_cell                                            1.0  1970.570000
# ...                                                   ...          ...
# trends_in_neuroscience                                1.0  2402.810000
# trends_in_neurosciences                               1.0  2426.960000
# trends_in_parasitology                                3.0  2257.653333
# trials                                                4.0  1200.475000
# trop_medicinal_international_health                   1.0  1834.770000
# tropical_animal_health_&_production                   1.0  2054.780000
# tropical_medicine_and_international_health            6.0  1843.163333
# tuberculosis                                          2.0  2161.255000
# urban_history                                         1.0  2034.000000
# urolithiasis                                          1.0  1112.400000
# vaccine                                               5.0  1623.394000
# vascular_pharmacology                                 1.0  2352.530000
# vet._journal                                          1.0  2480.060000
# veterinary_microbiologicalogy                         1.0  2451.490000
# veterinary_parasitology                               1.0  2488.170000
# veterinary_record                                     1.0  2040.000000
# veterinary_research                                   1.0     9.930000
# viral_hepatitis                                       1.0  2350.490000
# virol                                                 1.0  1604.820000
# virological_methods                                   1.0  2165.920000
# virology                                             11.0  1681.948182
# virology_journal                                      1.0  1242.000000
# virus_research                                        1.0  1947.090000
# vision                                                1.0  1157.880000
# vision_research                                       1.0  1456.180000
# visual_neuroscience                                   1.0  2034.000000
# visualized_experiements                               1.0   517.500000
# visualized_experiments                                6.0  2670.620000
# visulaized_expermiments                               1.0  2713.140000
# zoonoses_and_public_health                            1.0  2272.150000
#
#                                                            std      min  \
# Journal title
# abnormal_child_psychology_and_psychiatry                   NaN  2247.34
# abnormal_psychology                                        NaN  2534.53
# academy_of_nutrition_and_dietetics                         NaN  2379.54
# acquired_immune_deficiency_syndromes                199.978567  1834.77
# acquired_immune_deficiency_syndromes_behav                 NaN  1834.77
# acquired_immune_deficiency_syndromes_care           126.415851  2145.60
# acquired_immune_deficiency_syndromes_journal               NaN  2015.72
# acquired_immune_deficiency_syndromes_research_a...         NaN  1240.00
# acquired_immune_deficiency_syndromes_uk               0.000000  1836.92
# acquired_immune_deficiency_syndroms_(jacquired_...         NaN  1836.92
# acta_crystallographica,_section_d                          NaN   757.18
# acta_crystallographica_section_d,_biologicalogi...         NaN   771.42
# acta_crystallographica_section_d:_biologicalogi...         NaN   773.74
# acta_crystallographica_section_f:_structural_bi...   15.605847   785.60
# acta_crystallography_d                                     NaN   774.19
# acta_d                                                     NaN   750.16
# acta_dermato_venereologica                                 NaN   653.96
# acta_diabetologica                                         NaN  2336.28
# acta_f                                                     NaN   754.90
# acta_neuropathol                                           NaN  1901.04
# acta_neuropathologica                               244.811798  1884.01
# acta_opthalmologica                                        NaN  2270.16
# acta_physiol                                               NaN  1991.50
# addiction                                           306.481292  1919.51
# advances_in_experimental_medicine_and_biologica...    0.005000  1928.45
# affective_disorders                                 396.438813  1530.77
# age                                                 237.785868  2002.00
# age_and_ageing                                             NaN  2040.00
# ageing_&_society                                           NaN  1695.00
# aging_cell                                                 NaN  1970.57
# ...                                                        ...      ...
# trends_in_neuroscience                                     NaN  2402.81
# trends_in_neurosciences                                    NaN  2426.96
# trends_in_parasitology                              232.279561  2004.74
# trials                                              100.764590  1130.40
# trop_medicinal_international_health                        NaN  1834.77
# tropical_animal_health_&_production                        NaN  2054.78
# tropical_medicine_and_international_health          161.141743  1530.77
# tuberculosis                                        228.133861  1999.94
# urban_history                                              NaN  2034.00
# urolithiasis                                               NaN  1112.40
# vaccine                                             394.821486  1428.68
# vascular_pharmacology                                      NaN  2352.53
# vet._journal                                               NaN  2480.06
# veterinary_microbiologicalogy                              NaN  2451.49
# veterinary_parasitology                                    NaN  2488.17
# veterinary_record                                          NaN  2040.00
# veterinary_research                                        NaN     9.93
# viral_hepatitis                                            NaN  2350.49
# virol                                                      NaN  1604.82
# virological_methods                                        NaN  2165.92
# virology                                            343.643209  1247.41
# virology_journal                                           NaN  1242.00
# virus_research                                             NaN  1947.09
# vision                                                     NaN  1157.88
# vision_research                                            NaN  1456.18
# visual_neuroscience                                        NaN  2034.00
# visualized_experiements                                    NaN   517.50
# visualized_experiments                              671.411627  1424.71
# visulaized_expermiments                                    NaN  2713.14
# zoonoses_and_public_health                                 NaN  2272.15
#
#                                                           25%       50%  \
# Journal title
# abnormal_child_psychology_and_psychiatry            2247.3400  2247.340
# abnormal_psychology                                 2534.5300  2534.530
# academy_of_nutrition_and_dietetics                  2379.5400  2379.540
# acquired_immune_deficiency_syndromes                1968.6300  2009.650
# acquired_immune_deficiency_syndromes_behav          1834.7700  1834.770
# acquired_immune_deficiency_syndromes_care           2210.9550  2316.010
# acquired_immune_deficiency_syndromes_journal        2015.7200  2015.720
# acquired_immune_deficiency_syndromes_research_a...  1240.0000  1240.000
# acquired_immune_deficiency_syndromes_uk             1836.9200  1836.920
# acquired_immune_deficiency_syndroms_(jacquired_...  1836.9200  1836.920
# acta_crystallographica,_section_d                    757.1800   757.180
# acta_crystallographica_section_d,_biologicalogi...   771.4200   771.420
# acta_crystallographica_section_d:_biologicalogi...   773.7400   773.740
# acta_crystallographica_section_f:_structural_bi...   791.1175   796.635
# acta_crystallography_d                               774.1900   774.190
# acta_d                                               750.1600   750.160
# acta_dermato_venereologica                           653.9600   653.960
# acta_diabetologica                                  2336.2800  2336.280
# acta_f                                               754.9000   754.900
# acta_neuropathol                                    1901.0400  1901.040
# acta_neuropathologica                               2067.4900  2250.970
# acta_opthalmologica                                 2270.1600  2270.160
# acta_physiol                                        1991.5000  1991.500
# addiction                                           2027.8675  2136.225
# advances_in_experimental_medicine_and_biologica...  1928.4575  1928.460
# affective_disorders                                 2095.3775  2303.535
# age                                                 2086.0700  2170.140
# age_and_ageing                                      2040.0000  2040.000
# ageing_&_society                                    1695.0000  1695.000
# aging_cell                                          1970.5700  1970.570
# ...                                                       ...       ...
# trends_in_neuroscience                              2402.8100  2402.810
# trends_in_neurosciences                             2426.9600  2426.960
# trends_in_parasitology                              2155.7600  2306.780
# trials                                              1149.9750  1160.750
# trop_medicinal_international_health                 1834.7700  1834.770
# tropical_animal_health_&_production                 2054.7800  2054.780
# tropical_medicine_and_international_health          1845.2700  1883.625
# tuberculosis                                        2080.5975  2161.255
# urban_history                                       2034.0000  2034.000
# urolithiasis                                        1112.4000  1112.400
# vaccine                                             1433.3400  1448.380
# vascular_pharmacology                               2352.5300  2352.530
# vet._journal                                        2480.0600  2480.060
# veterinary_microbiologicalogy                       2451.4900  2451.490
# veterinary_parasitology                             2488.1700  2488.170
# veterinary_record                                   2040.0000  2040.000
# veterinary_research                                    9.9300     9.930
# viral_hepatitis                                     2350.4900  2350.490
# virol                                               1604.8200  1604.820
# virological_methods                                 2165.9200  2165.920
# virology                                            1492.2450  1577.910
# virology_journal                                    1242.0000  1242.000
# virus_research                                      1947.0900  1947.090
# vision                                              1157.8800  1157.880
# vision_research                                     1456.1800  1456.180
# visual_neuroscience                                 2034.0000  2034.000
# visualized_experiements                              517.5000   517.500
# visualized_experiments                              2676.9125  2702.200
# visulaized_expermiments                             2713.1400  2713.140
# zoonoses_and_public_health                          2272.1500  2272.150
#
#                                                           75%      max
# Journal title
# abnormal_child_psychology_and_psychiatry            2247.3400  2247.34
# abnormal_psychology                                 2534.5300  2534.53
# academy_of_nutrition_and_dietetics                  2379.5400  2379.54
# acquired_immune_deficiency_syndromes                2034.7500  2374.52
# acquired_immune_deficiency_syndromes_behav          1834.7700  1834.77
# acquired_immune_deficiency_syndromes_care           2399.2800  2399.28
# acquired_immune_deficiency_syndromes_journal        2015.7200  2015.72
# acquired_immune_deficiency_syndromes_research_a...  1240.0000  1240.00
# acquired_immune_deficiency_syndromes_uk             1836.9200  1836.92
# acquired_immune_deficiency_syndroms_(jacquired_...  1836.9200  1836.92
# acta_crystallographica,_section_d                    757.1800   757.18
# acta_crystallographica_section_d,_biologicalogi...   771.4200   771.42
# acta_crystallographica_section_d:_biologicalogi...   773.7400   773.74
# acta_crystallographica_section_f:_structural_bi...   802.1525   807.67
# acta_crystallography_d                               774.1900   774.19
# acta_d                                               750.1600   750.16
# acta_dermato_venereologica                           653.9600   653.96
# acta_diabetologica                                  2336.2800  2336.28
# acta_f                                               754.9000   754.90
# acta_neuropathol                                    1901.0400  1901.04
# acta_neuropathologica                               2299.5900  2348.21
# acta_opthalmologica                                 2270.1600  2270.16
# acta_physiol                                        1991.5000  1991.50
# addiction                                           2244.5825  2352.94
# advances_in_experimental_medicine_and_biologica...  1928.4600  1928.46
# affective_disorders                                 2331.8775  2357.04
# age                                                 2254.2100  2338.28
# age_and_ageing                                      2040.0000  2040.00
# ageing_&_society                                    1695.0000  1695.00
# aging_cell                                          1970.5700  1970.57
# ...                                                       ...      ...
# trends_in_neuroscience                              2402.8100  2402.81
# trends_in_neurosciences                             2426.9600  2426.96
# trends_in_parasitology                              2384.1100  2461.44
# trials                                              1211.2500  1350.00
# trop_medicinal_international_health                 1834.7700  1834.77
# tropical_animal_health_&_production                 2054.7800  2054.78
# tropical_medicine_and_international_health          1936.2225  1974.72
# tuberculosis                                        2241.9125  2322.57
# urban_history                                       2034.0000  2034.00
# urolithiasis                                        1112.4000  1112.40
# vaccine                                             1477.7300  2328.84
# vascular_pharmacology                               2352.5300  2352.53
# vet._journal                                        2480.0600  2480.06
# veterinary_microbiologicalogy                       2451.4900  2451.49
# veterinary_parasitology                             2488.1700  2488.17
# veterinary_record                                   2040.0000  2040.00
# veterinary_research                                    9.9300     9.93
# viral_hepatitis                                     2350.4900  2350.49
# virol                                               1604.8200  1604.82
# virological_methods                                 2165.9200  2165.92
# virology                                            1886.8200  2421.96
# virology_journal                                    1242.0000  1242.00
# virus_research                                      1947.0900  1947.09
# vision                                              1157.8800  1157.88
# vision_research                                     1456.1800  1456.18
# visual_neuroscience                                 2034.0000  2034.00
# visualized_experiements                              517.5000   517.50
# visualized_experiments                              3106.4850  3284.88
# visulaized_expermiments                             2713.1400  2713.14
# zoonoses_and_public_health                          2272.1500  2272.15
#
# [833 rows x 8 columns]
